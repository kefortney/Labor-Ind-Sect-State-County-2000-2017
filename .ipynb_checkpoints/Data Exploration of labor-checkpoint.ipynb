# %%
import pandas as pd
import numpy as np
# Visualization
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
# %matplotlib inline

# %%
# Load cumilative datasets created in step 1
cumllaborcnty = pd.read_csv('cumllaborcnty.csv')
cumllaborvt = pd.read_csv('cumllaborvt.csv')

# %%
cumllaborcnty = pd.melt(cumllaborcnty,id_vars=['Year','County','Type'],var_name='Time', value_name='Count')
cumllaborcnty.head()
# Out:
#    Year          County                                        Type Time  \
# 0  2017  Addison County             Total Covered -  all ownerships  Jan
# 1  2017  Addison County                           Private ownership  Jan
# 2  2017  Addison County                      Goods Producing domain  Jan
# 3  2017  Addison County    Natural Resources and Mining supersector  Jan
# 4  2017  Addison County  Agriculture, forestry, fishing and hunting  Jan
#
#    Count
# 0  13094
# 1  11078
# 2   3259
# 3    459
# 4    421

# %%
# There are missing values or occasions where the occurance is too small to show, each we are replacing with NaNs
cumllaborcnty = cumllaborcnty.replace('(c)', np.nan)
cumllaborcnty = cumllaborcnty.replace('-', np.nan)
cumllaborcnty = cumllaborcnty.replace('na', np.nan)
cumllaborcnty = cumllaborcnty.replace(' ', np.nan)
cumllaborcnty = cumllaborcnty.replace('<1', 1)
cumllaborcnty['Count'] = pd.to_numeric(cumllaborcnty['Count'])

# %%
cumllaborcnty.head()
# Out:
#    Year          County                                        Type Time  \
# 0  2017  Addison County             Total Covered -  all ownerships  Jan
# 1  2017  Addison County                           Private ownership  Jan
# 2  2017  Addison County                      Goods Producing domain  Jan
# 3  2017  Addison County    Natural Resources and Mining supersector  Jan
# 4  2017  Addison County  Agriculture, forestry, fishing and hunting  Jan
#
#      Count
# 0  13094.0
# 1  11078.0
# 2   3259.0
# 3    459.0
# 4    421.0

# %%
# Set up lists of how these are going to be split out into similiar types
monthlist = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

quarterslist = ['Average Employment Qtr 1', 'Average Employment Qtr 2', 'Average Employment Qtr 3', 'Average Employment Qtr 4', 
            'Average Female Employment Qtr 1', 'Average Female Employment Qtr 2','Average Female Employment Qtr 3',
            'Average Female Employment Qtr 4','Total Wages Qtr 1', 'Total Wages 2', 'Total Wages 3', 
            'Total Wages 4','Average Wage Qtr 1', 'Average Wage Qtr 2', 'Average Wage Qtr 3', 
            'Average Wage Qtr 4','Number of Establishments Qtr 1', 'Number of Establishments Qtr 2',
            'Number of Establishments Qtr 3', 'Number of EstablishmentsQtr 4'
           ]

annuallist = ['Average Employment Annual', 'Average Female Employment Annual', 'Total Wages Annual',  'Average Wage Annual',
           'Number of Establishments Annual'
          ]

# %%
months = cumllaborcnty[cumllaborcnty['Time'].isin(monthlist)].copy()
quarters = cumllaborcnty[cumllaborcnty['Time'].isin(quarterslist)].copy()
annual = cumllaborcnty[cumllaborcnty['Time'].isin(annuallist)].copy()

# %%
quarters.head()
# Out:
#         Year          County                                        Type  \
# 114156  2017  Addison County             Total Covered -  all ownerships
# 114157  2017  Addison County                           Private ownership
# 114158  2017  Addison County                      Goods Producing domain
# 114159  2017  Addison County    Natural Resources and Mining supersector
# 114160  2017  Addison County  Agriculture, forestry, fishing and hunting
#
#                             Time    Count
# 114156  Average Employment Qtr 1  13162.0
# 114157  Average Employment Qtr 1  11121.0
# 114158  Average Employment Qtr 1   3270.0
# 114159  Average Employment Qtr 1    474.0
# 114160  Average Employment Qtr 1    437.0

# %%
quarters['Quarter'] = np.nan

# %%
quarters.loc[quarters['Time'].str.endswith("Qtr 1"), "Quarter"] = "1"
quarters.loc[quarters['Time'].str.endswith("Qtr 2"), "Quarter"] = "2"
quarters.loc[quarters['Time'].str.endswith("Qtr 3"), "Quarter"] = "3"
quarters.loc[quarters['Time'].str.endswith("Qtr 4"), "Quarter"] = "4"
quarters['Time'] = quarters['Time'].str[:-6]

# %%
pd.unique(quarters['Time'])
# Out:
# array(['Average Employment', 'Average Female Employment', 'Total Wages',
#        'Average Wage', 'Number of Establishments'], dtype=object)

# %%
quarters.columns
# Out:
# Index(['Year', 'County', 'Type', 'Time', 'Count', 'Quarter'], dtype='object')

# %%
quarters.columns = ['Year', 'County', 'Type', 'Stat', 'Count', 'Quarter']
quarters = quarters[['Year', 'Quarter', 'County', 'Type', 'Stat', 'Count', ]]

# %%
quarters.head()
# Out:
#         Year Quarter          County  \
# 114156  2017       1  Addison County
# 114157  2017       1  Addison County
# 114158  2017       1  Addison County
# 114159  2017       1  Addison County
# 114160  2017       1  Addison County
#
#                                               Type                Stat  \
# 114156             Total Covered -  all ownerships  Average Employment
# 114157                           Private ownership  Average Employment
# 114158                      Goods Producing domain  Average Employment
# 114159    Natural Resources and Mining supersector  Average Employment
# 114160  Agriculture, forestry, fishing and hunting  Average Employment
#
#           Count
# 114156  13162.0
# 114157  11121.0
# 114158   3270.0
# 114159    474.0
# 114160    437.0

# %%
test = quarters.pivot(columns='Stat', values='Count')

test2 = pd.pivot_table(quarters, values='Count', index=['Year','Quarter','County','Type'], columns=['Stat'])
test2 = test2.reset_index()

# %%
test2.head(40)
# Out:
# Stat  Year Quarter            County  \
# 0     2017       1    Addison County
# 1     2017       1    Addison County
# 2     2017       1    Addison County
# 3     2017       1    Addison County
# 4     2017       1    Addison County
# 5     2017       1    Addison County
# 6     2017       1    Addison County
# 7     2017       1    Addison County
# 8     2017       1    Addison County
# 9     2017       1    Addison County
# 10    2017       1    Addison County
# 11    2017       1    Addison County
# 12    2017       1    Addison County
# 13    2017       1    Addison County
# 14    2017       1    Addison County
# 15    2017       1    Addison County
# 16    2017       1    Addison County
# 17    2017       1    Addison County
# 18    2017       1    Addison County
# 19    2017       1    Addison County
# 20    2017       1    Addison County
# 21    2017       1    Addison County
# 22    2017       1    Addison County
# 23    2017       1    Addison County
# 24    2017       1    Addison County
# 25    2017       1    Addison County
# 26    2017       1    Addison County
# 27    2017       1    Addison County
# 28    2017       1    Addison County
# 29    2017       1    Addison County
# 30    2017       1    Addison County
# 31    2017       1    Addison County
# 32    2017       1    Addison County
# 33    2017       1    Addison County
# 34    2017       1    Addison County
# 35    2017       1    Addison County
# 36    2017       1    Addison County
# 37    2017       1    Addison County
# 38    2017       1  All Other county
# 39    2017       1  All Other county
#
# Stat                                               Type  Average Employment  \
# 0                       Accommodation and food services          860.000000
# 1                     Administrative and waste services          162.727273
# 2            Agriculture, forestry, fishing and hunting          532.125000
# 3                   Arts, entertainment, and recreation          109.111111
# 4                              Construction supersector          636.000000
# 5                           Durable Goods manufacturing         1243.944444
# 6             Education and Health Services supersector         3526.722222
# 7                                  Educational services                 NaN
# 8                                    Federal Government          123.611111
# 9                                 Finance and insurance          329.944444
# 10                     Financial Activities supersector          411.333333
# 11                               Goods Producing domain         3163.944444
# 12                    Health care and social assistance                 NaN
# 13                              Information supersector           99.833333
# 14                  Leisure and Hospitality supersector          969.000000
# 15                                     Local government         1762.277778
# 16              Management of companies and enterprises                 NaN
# 17                            Manufacturing supersector         1971.611111
# 18                                               Mining           22.125000
# 19             Natural Resources and Mining supersector          556.111111
# 20                      Non-Durable Goods manufacturing          727.611111
# 21    Other services, except public administration s...          351.333333
# 22                                    Private ownership        11614.666667
# 23       Professional and Business Services supersector          636.833333
# 24                  Professional and technical services          469.277778
# 25                   Real estate and rental and leasing           81.500000
# 26                                         Retail trade         1869.277778
# 27                             Service Providing domain         8450.666667
# 28                                     State government          166.611111
# 29                      Total Covered -  all ownerships        13667.222222
# 30     Trade, Transportation, and Utilities supersector         2455.444444
# 31                       Transportation and warehousing          323.428571
# 32                     Unspecified industry supersector                 NaN
# 33                                            Utilities                 NaN
# 34                                      Wholesale trade          297.000000
# 35                                released: August 2017                 NaN
# 36                              released: November 2017                 NaN
# 37                             released: September 2016                 NaN
# 38                      Accommodation and food services           38.333333
# 39                    Administrative and waste services          535.000000
#
# Stat  Average Female Employment  Average Wage  Number of Establishments  \
# 0                    497.375000   3928.166667                 75.222222
# 1                     56.090909   6923.000000                 58.333333
# 2                    107.000000   6665.937500                 74.277778
# 3                     64.687500   3980.555556                 15.888889
# 4                     87.812500   9351.444444                174.666667
# 5                    418.562500  14225.333333                 34.833333
# 6                   2353.875000   9569.055556                130.888889
# 7                           NaN           NaN                 21.166667
# 8                           NaN  10728.166667                 30.888889
# 9                    236.125000  11727.277778                 40.777778
# 10                   280.500000  10588.777778                 70.833333
# 11                   859.312500  10967.500000                318.555556
# 12                          NaN           NaN                109.722222
# 13                    53.625000   7194.166667                 18.166667
# 14                   562.062500   3924.611111                 91.111111
# 15                  1226.562500   7775.333333                 61.666667
# 16                          NaN           NaN                  1.000000
# 17                   662.562500  12710.166667                 63.833333
# 18                     2.142857   9832.562500                  5.777778
# 19                   108.937500   6787.055556                 80.055556
# 20                   244.000000   9985.444444                 29.000000
# 21                   200.000000   6192.833333                108.722222
# 22                  5684.875000   8958.055556               1217.444444
# 23                   326.187500  11154.166667                204.000000
# 24                   270.187500  12152.333333                145.277778
# 25                    44.375000   5854.833333                 30.055556
# 26                   891.875000   6761.055556                182.777778
# 27                  4825.562500   8217.833333                898.888889
# 28                    86.375000  10237.722222                 11.555556
# 29                          NaN   8835.555556               1321.555556
# 30                  1049.312500   7148.444444                275.166667
# 31                    91.833333   6391.357143                 31.833333
# 32                          NaN           NaN                       NaN
# 33                          NaN           NaN                  2.111111
# 34                    74.750000   8222.250000                 58.444444
# 35                          NaN           NaN                       NaN
# 36                          NaN           NaN                       NaN
# 37                          NaN           NaN                       NaN
# 38                    18.500000   9076.000000                  6.555556
# 39                   193.214286   8710.062500                108.722222
#
# Stat    Total Wages
# 0       3373.055556
# 1       1121.363636
# 2       3631.437500
# 3        437.000000
# 4       5953.166667
# 5      17525.055556
# 6      34188.555556
# 7               NaN
# 8       1310.444444
# 9       3872.833333
# 10      4328.944444
# 11     34478.222222
# 12              NaN
# 13       704.166667
# 14      3810.055556
# 15     13634.611111
# 16              NaN
# 17     24675.222222
# 18       206.687500
# 19      3849.833333
# 20      7150.111111
# 21      2183.388889
# 22    104404.277778
# 23      7143.277778
# 24      5724.222222
# 25       456.055556
# 26     12655.555556
# 27     69926.166667
# 28      1688.944444
# 29    121038.444444
# 30     17567.722222
# 31      2078.428571
# 32              NaN
# 33              NaN
# 34      2436.750000
# 35              NaN
# 36              NaN
# 37              NaN
# 38       327.000000
# 39      4798.750000

# %%
# Clean up the column order and then sort everything
months.sort_values(by=['County','Year','Time'])
months.shape

# %% [markdown]
# ## Exploring the Data
#
# At this point what we have is month over month employment counts for 17 years by industry at various levels. First we are going to tackle the supersectors and see what they look like in box plots. Box plots are a standardized way of displaying the distribution of data based on the five number summary:
# * minimum (bottom T of the line)
# * first quartile (bottom of the box)
# * median (horizontal line bisecting the box)
# * third quartile (top of the box)
# * maximum. (top T of the line

# %%
natres = quarters[quarters['Type'] == 'Natural Resources and Mining supersector']

data = natres
sns.boxplot(x='Time', y='Count',  data=data)
plt.xticks(rotation=90)

# %%
data = natres
sns.boxplot(x='Time', y='Count', hue='County',  data=data)
plt.xticks(rotation=45)

# %%
const = months[months['Type'] == 'Construction supersector']

data = const
sns.boxplot(x='Month', y='Count',  data=data)
plt.xticks(rotation=90)

# %%
manf = months[months['Type'] == 'Manufacturing supersector']

data = manf
sns.boxplot(x='Month', y='Count',  data=data)
plt.xticks(rotation=90)

# %%
trade = months[months['Type'] == 'Trade, Transportation, and Utilities supersector']

data = trade
sns.boxplot(x='Month', y='Count',  data=data)
plt.xticks(rotation=90)

# %%
info = months[months['Type'] == 'Information supersector']
data = info
sns.boxplot(x='Month', y='Count', data=data)
plt.xticks(rotation=90)

# %%
fin = months[months['Type'] == 'Financial Activities supersector']
data = fin
sns.boxplot(x='Month', y='Count',  data=data)
plt.xticks(rotation=90)

# %%
busin = months[months['Type'] == 'Professional and Business Services supersector']
data = busin
sns.boxplot(x='Month', y='Count', data=data)
plt.xticks(rotation=90)

# %%
edhealth = months[months['Type'] == 'Education and Health Services supersector']
data = edhealth
sns.boxplot(x='Month', y='Count', data=data)
plt.xticks(rotation=90)

# %%
leis = months[months['Type'] == 'Leisure and Hospitality supersector']
data = leis
sns.boxplot(x='Month', y='Count', data=data)
plt.xticks(rotation=90)

# %%
other = months[months['Type'] == 'Other services, except public administration supersector']
data = other
sns.boxplot(x='Month', y='Count', data=data)
plt.xticks(rotation=90)

# %%
art = months[months['Type'] == 'Arts, entertainment, and recreation']
#art = months[months['Type'] == 'Leisure and Hospitality supersector']

art.head()

# %%
data = art[art['County'] == 'Chittenden County']
sns.boxplot(x='Month', y='Count',   data=data)
plt.xticks(rotation=90)

# %%
data = art[art['County'] == 'Washington County']
sns.boxplot(x='Month', y='Count',   data=data)
plt.xticks(rotation=90)

# %%
data = art
data = data[(data['County'] == 'Bennington County') |
          (data['County'] == 'Washington County') | 
          (data['County'] == 'Chittenden County') | 
          (data['County'] == 'Rutland County')]
sns.boxplot(x='Month', y='Count', hue='County',  data=data)
plt.xticks(rotation=90)

# %%
health = months[months['Type'] == 'Education and Health Services supersector']

# %%
sns.boxplot(x='County', y='Count', data=health)
plt.xticks(rotation=90)

# %%
pd.unique(months['Type'])

# %%
fin = months[months['Type'] == 'Financial Activities supersector']

# %%
sns.boxplot(x='County', y='Count',  data=fin)
plt.xticks(rotation=90)

# %%
tech = months[months['Type'] == 'Professional and Business Services supersector']

# %%
sns.boxplot(x='County', y='Count',  data=tech)
plt.xticks(rotation=90)

# %%
info = months[months['Type'] == 'Information supersector']

# %%
sns.boxplot(x='County', y='Count',  data=info)
plt.xticks(rotation=90)

# %%
healthed = months[months['Type'] == 'Education and Health Services supersector']

# %%
sns.boxplot(x='County', y='Count',  data=healthed)
plt.xticks(rotation=90)

# %%
fed = months[months['Type'] == 'Federal Government']

# %%
sns.boxplot(x='County', y='Count',  data=fed)
plt.xticks(rotation=90)

# %%
state = months[months['Type'] == 'State government']

# %%
sns.boxplot(x='County', y='Count',  data=state)
plt.xticks(rotation=90)
